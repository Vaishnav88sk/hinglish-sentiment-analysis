# %% [markdown]
# **BE3**
#
# **Batch: B**
#
# # NLP Mini Project
#
# **Group Members:**
# 1.   Kaif Khan **38**
# 2.   Pratik Naik **34**
# 3.   Niraj Parmar **36**

# %%
pip install stanza
# Out:
# Requirement already satisfied: stanza in ./venv/lib/python3.12/site-packages (1.11.1)
# Requirement already satisfied: emoji in ./venv/lib/python3.12/site-packages (from stanza) (2.15.0)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from stanza) (2.4.3)
# Requirement already satisfied: platformdirs in ./venv/lib/python3.12/site-packages (from stanza) (4.9.4)
# Requirement already satisfied: protobuf>=3.15.0 in ./venv/lib/python3.12/site-packages (from stanza) (7.34.1)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from stanza) (2.33.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from stanza) (3.6.1)
# Requirement already satisfied: torch>=1.13.0 in ./venv/lib/python3.12/site-packages (from stanza) (2.11.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from stanza) (4.67.3)
# Requirement already satisfied: udtools>=0.2.4 in ./venv/lib/python3.12/site-packages (from stanza) (0.2.7)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools<82 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (1.14.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in ./venv/lib/python3.12/site-packages (from torch>=1.13.0->stanza) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in ./venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.13.0->stanza) (13.0.85)
# Requirement already satisfied: udapi>=0.5.0 in ./venv/lib/python3.12/site-packages (from udtools>=0.2.4->stanza) (0.5.2)
# Requirement already satisfied: regex>=2020.09.27 in ./venv/lib/python3.12/site-packages (from udtools>=0.2.4->stanza) (2026.2.28)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->stanza) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests->stanza) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.12/site-packages (from requests->stanza) (2026.2.25)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.13.0->stanza) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Requirement already satisfied: colorama in ./venv/lib/python3.12/site-packages (from udapi>=0.5.0->udtools>=0.2.4->stanza) (0.4.6)
# Requirement already satisfied: termcolor in ./venv/lib/python3.12/site-packages (from udapi>=0.5.0->udtools>=0.2.4->stanza) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Imports and initialization of pipeline
import stanza
import string
import re

# %%
#For lemmatization
stanza.download('hi')
nlp_hi = stanza.Pipeline('hi')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json: 439kB [00:00, 12.9MB/s]
# 2026-04-16 13:04:57 INFO: Downloaded file to /home/vaishnavsk/.cache/stanza/1.11.0/resources/resources.json
# 2026-04-16 13:04:57 INFO: Downloading default packages for language: hi (Hindi) ...
# 2026-04-16 13:04:58 INFO: File exists: /home/vaishnavsk/.cache/stanza/1.11.0/resources/hi/default.zip
# 2026-04-16 13:05:00 INFO: Finished downloading models and saved to /home/vaishnavsk/.cache/stanza/1.11.0/resources
# 2026-04-16 13:05:00 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json: 439kB [00:00, 10.8MB/s]
# 2026-04-16 13:05:00 INFO: Downloaded file to /home/vaishnavsk/.cache/stanza/1.11.0/resources/resources.json
# 2026-04-16 13:05:01 INFO: Loading these models for language: hi (Hindi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | hdtb          |
# | pos       | hdtb_charlm   |
# | lemma     | hdtb_nocharlm |
# | depparse  | hdtb_charlm   |
# | ner       | ilner_charlm  |
# =============================
#
# 2026-04-16 13:05:01 INFO: Using device: cpu
# 2026-04-16 13:05:01 INFO: Loading: tokenize
# 2026-04-16 13:05:01 INFO: Loading: pos
# 2026-04-16 13:05:02 INFO: Loading: lemma
# 2026-04-16 13:05:03 INFO: Loading: depparse
# 2026-04-16 13:05:03 INFO: Loading: ner
# 2026-04-16 13:05:04 INFO: Done loading processors!

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/vaishnavsk/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # **Pre Processing**

# %%
#Function to tokenize
def tokenize(sentence):
    return sentence.split()

def filter(tokenString):
    #Remove numbers
    tokenString = re.sub(r"\d+", '', tokenString)
    #Remove URLS
    tokenString = re.sub(r'(https?|ftp|www)\S+', '', tokenString)
    #Remove punctuations
    exclist = string.punctuation
    table_ = tokenString.maketrans('', '', exclist)
    tokenString = tokenString.translate(table_)
    #Remove extra spaces
    tokenString = re.sub(' +'," ",tokenString).strip()
    #Remove hashtags
    tokenString = ''.join([x + ' ' for x in tokenString.split(" ") if not x.startswith("#")]).strip()
    #Remove emojis
    pattenr = re.compile(u'([\U00002600-\U000027BF])|([\U0001f300-\U0001f64F])|([\U0001f680-\U0001f6FF])')
    tokenString = pattenr.sub(r'',tokenString)
    return tokenString

def script_validation(tokens):
    for word in tokens:
        word = word.strip()
        for ch in word:
            c = ch
            if len(c) == 1:
                if ord(c) not in range(2304,2432):
                    return(0)
    return 1

def separate_into_dict(tokens):
    return {i:token for i,token in enumerate(tokens)}

#Function to remove stopwords
def hindiStopwordsRemover(hinDict):
    stopwords = ['मैं', 'मुझको', 'मेरा', 'अपने आप को', 'हमने', 'हमारा', 'अपना', 'हम', 'आप', 'आपका', 'तुम्हारा', 'अपने आप', 'स्वयं',
             'वह', 'इसे, उसके', 'खुद को', 'कि वह', 'उसकी', 'उसका', 'खुद ही', 'यह', 'इसके', 'उन्होने', 'अपने', 'क्या', 'जो', 'किसे',
             'किसको', 'कि', 'ये', 'हूँ', 'होता है', 'रहे', 'थी', 'थे', 'होना', 'गया', 'किया जा रहा है', 'किया है', 'है', 'पडा', 'होने', 'करना',
             'करता है', 'किया', 'रही', 'एक', 'लेकिन', 'अगर', 'या', 'क्यूंकि', 'जैसा', 'जब तक', 'जबकि', 'की', 'पर', 'द्वारा', 'के लिए', 'साथ',
             'के बारे में', 'खिलाफ', 'बीच', 'में', 'के माध्यम से', 'दौरान', 'से पहले', 'के बाद', 'ऊपर', 'नीचे', 'को', 'से', 'तक', 'से नीचे', 'करने में', 'निकल', 'बंद', 'से अधिक',
             'तहत', 'दुबारा', 'आगे', 'फिर', 'एक बार', 'यहाँ', 'वहाँ', 'कब', 'कहाँ', 'क्यों', 'कैसे', 'सारे', 'किसी', 'दोनो', 'प्रत्येक', 'ज्यादा', 'अधिकांश', 'अन्य', 'में कुछ', 'ऐसा', 
             'में कोई', 'मात्र', 'खुद', 'समान', 'इसलिए', 'बहुत', 'सकता', 'जायेंगे', 'जरा', 'चाहिए', 'अभी', 'और', 'कर दिया', 'रखें', 'का', 'हैं', 'इस', 'होता', 'करने', 'ने', 'बनी', 'तो',
             'ही', 'हो','इसका', 'था', 'हुआ', 'वाले', 'बाद', 'लिए', 'सकते', 'इसमें', 'दो', 'वे', 'करते', 'कहा', 'वर्ग', 'कई', 'करें', 'होती', 'अपनी', 'उनके', 'यदि', 'हुई', 'जा', 'कहते',
             'जब', 'होते', 'कोई', 'हुए', 'व', 'जैसे', 'सभी', 'करता', 'उनकी', 'तरह', 'उस', 'आदि', 'इसकी', 'उनका', 'इसी', 'पे', 'तथा', 'भी', 'परंतु', 'इन', 'कम', 'दूर', 'पूरे', 'गये', 
             'तुम', 'मै', 'यहां', 'हुये', 'कभी', 'अथवा', 'गयी', 'प्रति', 'जाता', 'इन्हें', 'गई', 'अब', 'जिसमें', 'लिया', 'बड़ा', 'जाती', 'तब', 'उसे', 'जाते', 'लेकर', 'बड़े', 'दूसरे', 'जाने',
             'बाहर', 'स्थान', 'उन्हें', 'गए', 'ऐसे', 'जिससे', 'समय', 'दोनों', 'किए', 'रहती', 'इनके', 'इनका', 'इनकी', 'सकती', 'आज', 'कल', 'जिन्हें', 'जिन्हों', 'तिन्हें', 'तिन्हों', 'किन्हों', 
             'किन्हें', 'इत्यादि', 'इन्हों', 'उन्हों', 'बिलकुल', 'निहायत', 'इन्हीं', 'उन्हीं', 'जितना', 'दूसरा', 'कितना', 'साबुत', 'वग़ैरह', 'कौनसा', 'लिये', 'दिया', 'जिसे', 'तिसे', 'काफ़ी', 'पहले',
             'बाला', 'मानो', 'अंदर', 'भीतर', 'पूरा', 'सारा', 'उनको', 'वहीं', 'जहाँ', 'जीधर', 'के', 'एवं', 'कुछ', 'कुल', 'रहा', 'जिस', 'जिन', 'तिस', 'तिन', 'कौन', 'किस', 'संग', 'यही',
             'बही', 'उसी', 'मगर', 'कर', 'मे', 'एस', 'उन', 'सो', 'अत' ]
    newHinDict = {}
    for index,hiToken in hinDict.items():
        if hiToken not in stopwords:
            newHinDict.update({index:hiToken})
    return newHinDict

#Function to lemmatize
def postagger_hi(lemmahin):                   
    newDict = {}
    keys = list(lemmahin.keys())
    values = list(lemmahin.values())

    string = ' '.join(values)
    dochi = nlp_hi(string)

    pos_list = []
    for sent in dochi.sentences:
        for word in sent.words:
            pos_list.append(word.text + '/' + word.upos)

    # ✅ Safe mapping
    for k, v in zip(keys, pos_list):
        newDict[k] = v

    return newDict

# Function to lemmatize Hindi words
def lemmatize_hi(hinDict):
    suffixes = ['ों', 'ें', 'ो', 'े', 'ी', 'ा', 'ि', 'ु', 'ू']
    
    newDict = {}

    for index, word in hinDict.items():
        lemma = word

        for suf in suffixes:
            if word.endswith(suf) and len(word) > len(suf) + 1:
                lemma = word[:-len(suf)]
                break

        newDict[index] = lemma

    return newDict

#Function to tag Part of Speech
def postagger_hi(lemmahin):                   
    newDict = {}
    keys = list(lemmahin.keys())
    values = list(lemmahin.values())

    string = ' '.join(values)
    dochi = nlp_hi(string)

    pos_list = []
    for sent in dochi.sentences:
        for word in sent.words:
            pos_list.append(word.text + '/' + word.upos)

    for k, v in zip(keys, pos_list):
        newDict[k] = v

    return newDict

#Function to handle negation
def negation_handling_hin(pos_dict):
    newDict = {}
    exclamation = False
    skip = False
    for index,word in pos_dict.items():
        actualWord = word.split("/")[0]
        pos = word.split("/")[1]
        #Check if the word is नहीं
        if actualWord == "नहीं":
            #Do backward negation
            skip = True
            #Get the list of words backwards
            wordsChange = reversed([(x,y) for x,y in newDict.items()])
            for i,w in wordsChange:
                #Get POS Tag
                p = w.split("/")[1]
                #Exclamation is Alive
                newWord = "!" + w
                #Update in the dictionary
                newDict.update({i : newWord})
                if p == 'ADJ' or p == 'NOUN' or p == 'VERB':
                    break
        elif actualWord == "न":
            #Do forward negation
            exclamation = not exclamation
            skip = True
            #Add the exclamation
            word = '!' + word
            #Check if the word is adjective, noun or a verb
            if pos == 'ADJ' or pos == 'NOUN' or pos == 'VERB':
                #Set exclamation to False
                exclamation = False
        if skip == False:
            newDict.update({index : word})
        else:
            skip = False
    return newDict

# %%
#For Calculating Sentiment
import pandas as pd
import os
hi_SWN = pd.read_csv(
    "hinSWN.csv",
    sep=',',          # or '\t' if tab-separated (very important!)
    header=None
)
length = hi_SWN[hi_SWN.columns[0]].count()

tagsDict = {
    "ADJ" : "a",
    "NOUN" : "n",
    "ADV" : "r",
    "VERB" : "v"
}

# %%
# def get_pos_tag(cols):
#     return cols[0]

# def get_words(cols):
#     words = cols[4].split(",")
#     return words

# def get_positive(cols):
#     return cols[2]

# def get_negative(cols):
#     return cols[3]

# def get_objective(cols):
#     return 1 - (float(cols[2]) + float(cols[3]))

def get_pos_tag(cols):
    return cols[0]

def get_words(cols):
    words = cols[4].split(",")
    return words

def get_positive(cols):
    return cols[2]

def get_negative(cols):
    return cols[3]

def get_objective(cols):
    return 1 - (float(cols[2]) + float(cols[3]))

# %% [markdown]
# # Extract Polarity

# %%
print("COLUMNS:", hi_SWN.columns)
print("FIRST ROW:", hi_SWN.iloc[0])

def get_scores(sentiword):
    res = 0
    wordList = {}
    count = 0
    score = 0.0

    for _, cols in hi_SWN.iterrows():   # ✅ FIXED
        words = get_words(cols)
        pos = get_pos_tag(cols)

        for word in sentiword:
            negate = False

            if word[0] == '!':
                negate = True
                actualWord = word[1:]
            else:
                actualWord = word

            actualWordW, tagWord = actualWord.split("/")

            if tagWord in ["ADJ", "ADV", "VERB", "NOUN"]:
                tag = tagsDict[tagWord]

                if actualWordW in words and pos == tag:
                    val = float(get_positive(cols)) - float(get_negative(cols))

                    if negate:
                        val *= -1

                    res += val
                    count += 1

                    wordList[actualWordW] = wordList.get(actualWordW, 0) + val

    if len(wordList) > 0:
        score = res / len(wordList)

    if score > 0:
        return ("Positive", score)
    elif score < 0:
        return ("Negative", score)

    return ("Neutral", score)

def sentiment(hinDict):
    return get_scores(list(hinDict.values()))
# Out:
# COLUMNS: Index([0, 1, 2, 3, 4], dtype='int64')
# FIRST ROW: 0         POS
# 1          ID
# 2    Positive
# 3    Negative
# 4      Synset
# Name: 0, dtype: str

# %%
pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in ./venv/lib/python3.12/site-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in ./venv/lib/python3.12/site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2026.2.25)
# Requirement already satisfied: hstspreload in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2025.1.1)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in ./venv/lib/python3.12/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in ./venv/lib/python3.12/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in ./venv/lib/python3.12/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in ./venv/lib/python3.12/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in ./venv/lib/python3.12/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googletrans import Translator

# %% [markdown]
# # Main

# %%
import nltk
nltk.download('punkt', download_dir='./nltk_data')
nltk.data.path.append('./nltk_data')

import re
import string
translator = Translator(service_urls=['translate.googleapis.com'])
#input_text = input("Enter Input Text: ")


comments = ["That restraurant is not good. Itna ghatiya khaana to kabhi nahi khaaya","ye khaana kitna taja hai","mera nam omkar hai"]

#Run task
for comment in comments:
    print("Raw Input:",comment)
    translation = translator.translate(comment, src='en', dest='hi')
    #Filter
    #print("Original:",comment)
    fitered_comment = filter(translation.text)
    print("After Translation:",fitered_comment)
    print("\n")
    #Tokenize
    tokens = tokenize(fitered_comment)
    print("After Tokenization:",tokens)
    print("\n")
    #Removing empty chararcters
    tokensFinal = [tokens[i] for i in range(len(tokens)) if len(tokens[i]) > 1 and tokens[i] != '']
    if script_validation(tokensFinal):
        #Converting tokens to dictionary
        tokDict = separate_into_dict(tokensFinal)
        #print(tokDict)
        #Removing stopwords
        stopRemoved = hindiStopwordsRemover(tokDict)
        print("Removed Stopwords:",stopRemoved)
        print("\n")
        #Lemmatization
        lemmHin = lemmatize_hi(stopRemoved)
        print("Lemmatization:",lemmHin)
        print("\n")
        #POS Tagging
        postag = postagger_hi(lemmHin)
        print("POS Tagging:",postag)
        print("\n")
        
        # for key, POSWord in postag.items():
        #   print(POSWord.split("/"))
        #Negation Handling
        negHin = negation_handling_hin(postag)
        print("Negation Handling:",negHin)
        print("\n")
        #Sentiment Score
        senti = sentiment(negHin)
        print(comment)
        print(senti)
        print("------------------------------------------------------\n")
# Out:
# Raw Input: That restraurant is not good. Itna ghatiya khaana to kabhi nahi khaaya
# [nltk_data] Downloading package punkt to ./nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# After Translation: वह रेस्टोरेंट अच्छा नहीं है इतना घटिया खाना तो कभी नहीं खाया
#
#
# After Tokenization: ['वह', 'रेस्टोरेंट', 'अच्छा', 'नहीं', 'है', 'इतना', 'घटिया', 'खाना', 'तो', 'कभी', 'नहीं', 'खाया']
#
#
# Removed Stopwords: {1: 'रेस्टोरेंट', 2: 'अच्छा', 3: 'नहीं', 5: 'इतना', 6: 'घटिया', 7: 'खाना', 10: 'नहीं', 11: 'खाया'}
#
#
# Lemmatization: {1: 'रेस्टोरेंट', 2: 'अच्छ', 3: 'नहीं', 5: 'इतन', 6: 'घटिय', 7: 'खान', 10: 'नहीं', 11: 'खाय'}
#
#
# POS Tagging: {1: 'रेस्टोरेंट/NOUN', 2: 'अच्छ/ADJ', 3: 'नहीं/PART', 5: 'इतन/ADJ', 6: 'घटिय/ADJ', 7: 'खान/NOUN', 10: 'नहीं/PART', 11: 'खाय/VERB'}
#
#
# Negation Handling: {1: 'रेस्टोरेंट/NOUN', 2: '!अच्छ/ADJ', 5: 'इतन/ADJ', 6: 'घटिय/ADJ', 7: '!खान/NOUN', 11: 'खाय/VERB'}
#
#
# That restraurant is not good. Itna ghatiya khaana to kabhi nahi khaaya
# ('Neutral', 0.0)
# ------------------------------------------------------
#
# Raw Input: ye khaana kitna taja hai
# After Translation: ये खाना कितना ताजा है
#
#
# After Tokenization: ['ये', 'खाना', 'कितना', 'ताजा', 'है']
#
#
# Removed Stopwords: {1: 'खाना', 3: 'ताजा'}
#
#
# Lemmatization: {1: 'खान', 3: 'ताज'}
#
#
# POS Tagging: {1: 'खान/PROPN', 3: 'ताज/PROPN'}
#
#
# Negation Handling: {1: 'खान/PROPN', 3: 'ताज/PROPN'}
#
#
# ye khaana kitna taja hai
# ('Neutral', 0.0)
# ------------------------------------------------------
#
# Raw Input: mera nam omkar hai
# After Translation: मेरा नाम ओंकार है
#
#
# After Tokenization: ['मेरा', 'नाम', 'ओंकार', 'है']
#
#
# Removed Stopwords: {1: 'नाम', 2: 'ओंकार'}
#
#
# Lemmatization: {1: 'नाम', 2: 'ओंकार'}
#
#
# POS Tagging: {1: 'नाम/NOUN', 2: 'ओंकार/NOUN'}
#
#
# Negation Handling: {1: 'नाम/NOUN', 2: 'ओंकार/NOUN'}
#
#
# mera nam omkar hai
# ('Neutral', 0.0)
# ------------------------------------------------------
